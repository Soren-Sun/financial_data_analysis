# %%
import pandas as pd
file_path=r"E:\数据表格\数据表格\《Python金融实战案例精粹（第2版）》的数据Excel文件\第3章\3.2 案例数据\2021年5月份的Euribor.xlsx"
df=pd.read_excel(file_path,sheet_name='Sheet1',header=0,index_col='日期')
df
# Out:
#                  1W       1M       3M       6M      12M
# 日期
# 2021-05-03 -0.00568 -0.00559 -0.00535 -0.00518 -0.00486
# 2021-05-04 -0.00570 -0.00562 -0.00535 -0.00516 -0.00483
# 2021-05-05 -0.00571 -0.00553 -0.00531 -0.00515 -0.00483
# 2021-05-06 -0.00571 -0.00558 -0.00532 -0.00513 -0.00483
# 2021-05-07 -0.00560 -0.00553 -0.00529 -0.00514 -0.00483
# 2021-05-10 -0.00559 -0.00551 -0.00533 -0.00513 -0.00482
# 2021-05-11 -0.00570 -0.00548 -0.00533 -0.00513 -0.00481
# 2021-05-12 -0.00566 -0.00552 -0.00539 -0.00513 -0.00480
# 2021-05-13 -0.00563 -0.00553 -0.00541 -0.00515 -0.00482
# 2021-05-14 -0.00567 -0.00561 -0.00549 -0.00513 -0.00478
# 2021-05-17 -0.00558 -0.00563 -0.00548 -0.00515 -0.00478
# 2021-05-18 -0.00563 -0.00559 -0.00553 -0.00515 -0.00476
# 2021-05-19 -0.00560 -0.00562 -0.00552 -0.00515 -0.00479
# 2021-05-20 -0.00563 -0.00562 -0.00545 -0.00517 -0.00482
# 2021-05-21 -0.00563 -0.00563 -0.00543 -0.00513 -0.00479
# 2021-05-24 -0.00559 -0.00561 -0.00542 -0.00509 -0.00478
# ...

# %%
df_head=df.head(5)

# %%
df_tail=df.tail(5)

# %%
df_head.to_excel('D:/桌面/dfhead.xlsx')

# %%
df_des=df.describe()

# %%
df_tail.to_csv('D:/桌面/dftail.csv')

# %%
df_des.to_csv('D:/桌面/df_des.text')
