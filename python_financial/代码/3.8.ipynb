# %%
import pandas as pd
import pylab as mp1
mp1.rcParams['font.sans-serif'] = ['KaiTi']  
file_path=r"E:\数据表格\数据表格\《Python金融实战案例精粹（第2版）》的数据Excel文件\第3章\3.8 案例数据\5只美国大型银行股收盘价数据.xlsx"
data=pd.read_excel(file_path,sheet_name='Sheet1',index_col='日期')
data=data.dropna(axis=0)

# %%
data_new=data/data.iloc[0]
data_new.plot(rot=90,figsize=(15,10))
# Out:
# <Axes: xlabel='日期'>

# %%
data.median()
# Out:
# 花旗         64.66
# 富国银行       48.88
# 美国银行       27.68
# 摩根大通      104.66
# 纽约梅隆银行     47.18
# dtype: float64

# %%
data.mean()
# Out:
# 花旗         61.851679
# 富国银行       46.893621
# 美国银行       26.896275
# 摩根大通      104.874316
# 纽约梅隆银行     46.230695
# dtype: float64

# %%
data.std()
# Out:
# 花旗        11.435437
# 富国银行      10.058060
# 美国银行       7.227593
# 摩根大通      26.633111
# 纽约梅隆银行     6.521636
# dtype: float64

# %%
data.skew()
# Out:
# 花旗       -0.480124
# 富国银行     -1.070941
# 美国银行     -0.055682
# 摩根大通      0.264034
# 纽约梅隆银行   -0.322453
# dtype: float64

# %%
data_new.kurt()
# Out:
# 花旗       -0.977728
# 富国银行      0.289394
# 美国银行     -0.171817
# 摩根大通     -0.277254
# 纽约梅隆银行   -0.886753
# dtype: float64

# %%
data.quantile([0.01,0.05,0.1,0.2])
# Out:
#            花旗     富国银行     美国银行    摩根大通  纽约梅隆银行
# 0.01  38.8684  22.8438  12.6244  57.040  32.855
# 0.05  42.0130  24.7120  13.6660  61.200  35.323
# 0.10  43.9420  27.5740  15.0740  65.280  36.856
# 0.20  48.6520  42.7180  22.6300  86.046  39.710
