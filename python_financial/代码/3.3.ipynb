# %%
import pandas as pd
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['KaiTi']  
# 解决负号显示问题
mpl.rcParams['axes.unicode_minus'] = False  
file_path=r"E:\数据表格\数据表格\《Python金融实战案例精粹（第2版）》的数据Excel文件\第3章\3.3 案例数据\科创50指数的数据.xlsx"
df=pd.read_excel(file_path,sheet_name='Sheet1',index_col='日期')
df
# Out:
#                  换手率
# 日期
# 2020-07-23  0.143346
# 2020-07-24  0.164279
# 2020-07-27  0.099435
# 2020-07-28  0.087226
# 2020-07-29  0.117381
# ...              ...
# 2021-09-24  0.050702
# 2021-09-27  0.059415
# 2021-09-28  0.041424
# 2021-09-29  0.048817
# 2021-09-30  0.038783
#
# [292 rows x 1 columns]

# %%
df.plot(rot=90,title='科创指数换手率',ylabel='换手率',grid=True)
# Out:
# <Axes: title={'center': '科创指数换手率'}, xlabel='日期', ylabel='换手率'>

# %%
df2=pd.read_excel(file_path,sheet_name='Sheet2',index_col='日期')
df2.plot(kind='hist',rot=90,title='成交量分布直方图',grid=True)
# Out:
# <Axes: title={'center': '成交量分布直方图'}, ylabel='Frequency'>

# %%
df2.plot(kind='box',rot=90,title='成交量分布箱型图',fontsize=16)
# Out:
# <Axes: title={'center': '成交量分布箱型图'}>

# %%
df3=pd.read_excel(file_path,sheet_name='Sheet3',index_col='日期')
df3
# Out:
#                   开盘价        最高价        最低价        收盘价
# 日期
# 2020-07-23  1487.1965  1512.4677  1459.7342  1494.1393
# 2020-07-24  1467.1027  1474.4601  1389.3051  1389.3051
# 2020-07-27  1396.4882  1403.1125  1361.9814  1374.5189
# 2020-07-28  1385.7933  1404.9026  1383.2842  1400.5353
# 2020-07-29  1400.9201  1476.9248  1395.9744  1476.9248
# ...               ...        ...        ...        ...
# 2021-09-24  1362.9793  1390.5031  1359.8450  1374.9995
# 2021-09-27  1386.5235  1397.1804  1354.2019  1368.6905
# 2021-09-28  1362.3276  1379.5922  1350.7940  1354.0959
# 2021-09-29  1344.8873  1356.6437  1336.5058  1345.7697
# 2021-09-30  1348.6497  1371.4941  1348.6497  1368.7158
#
# [292 rows x 4 columns]

# %%
df3.plot(kind='line',rot=90,subplots=True,layout=(2,2),figsize=(12,3),fontsize=8)
# Out:
# array([[<Axes: xlabel='日期'>, <Axes: xlabel='日期'>],
#        [<Axes: xlabel='日期'>, <Axes: xlabel='日期'>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'KaiTi'
plt.rcParams['axes.unicode_minus'] = False
import numpy as np
import pandas as pd
fig=plt.figure(figsize=(16,10))
plt.plot(df3['开盘价'],linestyle='--',c='r',marker='o',label='开盘价')
plt.plot(df3['开盘价'],linestyle=':',c='b',marker='>',label='收盘价')
plt.legend()
